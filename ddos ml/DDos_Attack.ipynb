# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn import svm
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import xgbclassifier
from xgboost import xgbclassifier
import xgboost as xgb
from sklearn.metrics import jaccard_similarity_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-dfec0bc775ae> in <module>
#       7 from sklearn.linear_model import LogisticRegression
#       8 from sklearn.neighbors import KNeighborsClassifier
# ----> 9 from sklearn.ensemble import xgbclassifier
#      10 from xgboost import xgbclassifier
#      11 import xgboost as xgb
#
# ImportError: cannot import name 'xgbclassifier' from 'sklearn.ensemble' (C:\Users\Shreya\anaconda3\lib\site-packages\sklearn\ensemble\__init__.py)

# %%
df = pd.read_csv('cybersecurity_training.csv',  sep='|', index_col=False)

# %%
df.head(100)
# Out:
#    alert_ids client_code  notified categoryname             ip  \
# 0        Nhq         DPM         0       Attack    YT.LB.32.21
# 1        XZt         FIN         0      Exploit   192.SL.UK.94
# 2        bBz         CHP         0       Attack    YT.LB.38.21
# 3        ZNr         HPS         0       Attack    JX.NY.13.20
# 4        poV         OSC         0       Attack    YT.LB.32.21
# ..       ...         ...       ...          ...            ...
# 95       SmU         LTN         0       Attack    OQ.QJ.38.32
# 96       AGF         GEP         0      Exploit   JQ.PJ.190.11
# 97       kxJ         TZS         0       Attack    YT.LB.32.21
# 98       VKN         ODR         1      Exploit    10.ZQ.RC.62
# 99       lds         OWD         0      Exploit  JM.OS.196.189
#
#    ipcategory_name ipcategory_scope  parent_category grandparent_category  \
# 0         INTERNET         Internet                7                    A
# 1         PRIV-192  Private network                1                    A
# 2         INTERNET         Internet                7                    A
# 3         INTERNET         Internet                7                    A
# 4         INTERNET         Internet                7                    A
# ..             ...              ...              ...                  ...
# 95        INTERNET         Internet                7                    A
# 96        INTERNET         Internet                7                    A
# 97        INTERNET         Internet                7                    A
# 98         PRIV-10  Private network                1                    A
# 99        INTERNET         Internet                7                    A
#
#     overallseverity  ...  thrcnt_week  thrcnt_day  p6  p9 p5m  p5w  p5d  p8m  \
# 0                 3  ...         4160         675   1   0   2    1    1    1
# 1                 5  ...            9           2   4  12   3    2    2    2
# 2                 4  ...         3788         628   1   0   2    2    1    2
# 3                 4  ...          565          96   0   0   2    2    2    2
# 4                 4  ...         2790         632   1   0   1    1    1    1
# ..              ...  ...          ...         ...  ..  ..  ..  ...  ...  ...
# 95                5  ...         3256         240   2   0   1    1    1    2
# 96                5  ...            9           2   0   0   4    2    1    4
# 97                5  ...         2081         723   2   0   1    1    1    1
# 98                3  ...           35           8   0   0   1    1    1    1
# 99                3  ...           20           4   0   0   1    1    1    1
#
#     p8w  p8d
# 0     1    1
# 1     1    1
# 2     2    1
# 3     2    2
# 4     1    1
# ..  ...  ...
# 95    1    1
# 96    2    1
# 97    1    1
# 98    1    1
# 99    1    1
#
# [100 rows x 63 columns]

# %%
list(df.columns)
missing_data = df.isnull()

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# alert_ids
# False    39427
# Name: alert_ids, dtype: int64
#
# client_code
# False    39427
# Name: client_code, dtype: int64
#
# notified
# False    39427
# Name: notified, dtype: int64
#
# categoryname
# False    39427
# Name: categoryname, dtype: int64
#
# ip
# False    39427
# Name: ip, dtype: int64
#
# ipcategory_name
# False    39427
# Name: ipcategory_name, dtype: int64
#
# ipcategory_scope
# False    39427
# Name: ipcategory_scope, dtype: int64
#
# parent_category
# False    39427
# Name: parent_category, dtype: int64
#
# grandparent_category
# False    39427
# Name: grandparent_category, dtype: int64
#
# overallseverity
# False    39427
# Name: overallseverity, dtype: int64
#
# timestamp_dist
# False    39427
# Name: timestamp_dist, dtype: int64
#
# start_hour
# False    39427
# Name: start_hour, dtype: int64
#
# start_minute
# False    39427
# Name: start_minute, dtype: int64
#
# start_second
# False    39427
# Name: start_second, dtype: int64
#
# weekday
# False    39427
# Name: weekday, dtype: int64
#
# correlatedcount
# False    39427
# Name: correlatedcount, dtype: int64
#
# n1
# True     32295
# False     7132
# Name: n1, dtype: int64
#
# n2
# True     32295
# False     7132
# Name: n2, dtype: int64
#
# n3
# True     32295
# False     7132
# Name: n3, dtype: int64
#
# n4
# True     32295
# False     7132
# Name: n4, dtype: int64
#
# n5
# True     32295
# False     7132
# Name: n5, dtype: int64
#
# n6
# True     32295
# False     7132
# Name: n6, dtype: int64
#
# n7
# True     32295
# False     7132
# Name: n7, dtype: int64
#
# n8
# True     32295
# False     7132
# Name: n8, dtype: int64
#
# n9
# True     32295
# False     7132
# Name: n9, dtype: int64
#
# n10
# True     32295
# False     7132
# Name: n10, dtype: int64
#
# score
# True     32295
# False     7132
# Name: score, dtype: int64
#
# srcip_cd
# False    39427
# Name: srcip_cd, dtype: int64
#
# dstip_cd
# False    39427
# Name: dstip_cd, dtype: int64
#
# srcport_cd
# False    39427
# Name: srcport_cd, dtype: int64
#
# dstport_cd
# False    39427
# Name: dstport_cd, dtype: int64
#
# alerttype_cd
# False    39427
# Name: alerttype_cd, dtype: int64
#
# direction_cd
# False    39427
# Name: direction_cd, dtype: int64
#
# eventname_cd
# False    39427
# Name: eventname_cd, dtype: int64
#
# severity_cd
# False    39427
# Name: severity_cd, dtype: int64
#
# reportingdevice_cd
# False    39427
# Name: reportingdevice_cd, dtype: int64
#
# devicetype_cd
# False    39427
# Name: devicetype_cd, dtype: int64
#
# devicevendor_cd
# False    39427
# Name: devicevendor_cd, dtype: int64
#
# domain_cd
# False    39427
# Name: domain_cd, dtype: int64
#
# protocol_cd
# False    39427
# Name: protocol_cd, dtype: int64
#
# username_cd
# False    39427
# Name: username_cd, dtype: int64
#
# srcipcategory_cd
# False    39427
# Name: srcipcategory_cd, dtype: int64
#
# dstipcategory_cd
# False    39427
# Name: dstipcategory_cd, dtype: int64
#
# isiptrusted
# False    39427
# Name: isiptrusted, dtype: int64
#
# untrustscore
# False    39427
# Name: untrustscore, dtype: int64
#
# flowscore
# False    39427
# Name: flowscore, dtype: int64
#
# trustscore
# False    39427
# Name: trustscore, dtype: int64
#
# enforcementscore
# False    39427
# Name: enforcementscore, dtype: int64
#
# dstipcategory_dominate
# False    39427
# Name: dstipcategory_dominate, dtype: int64
#
# srcipcategory_dominate
# False    39427
# Name: srcipcategory_dominate, dtype: int64
#
# dstportcategory_dominate
# False    39427
# Name: dstportcategory_dominate, dtype: int64
#
# srcportcategory_dominate
# False    39427
# Name: srcportcategory_dominate, dtype: int64
#
# thrcnt_month
# False    39427
# Name: thrcnt_month, dtype: int64
#
# thrcnt_week
# False    39427
# Name: thrcnt_week, dtype: int64
#
# thrcnt_day
# False    39427
# Name: thrcnt_day, dtype: int64
#
# p6
# False    39427
# Name: p6, dtype: int64
#
# p9
# False    39427
# Name: p9, dtype: int64
#
# p5m
# False    39427
# Name: p5m, dtype: int64
#
# p5w
# False    39427
# Name: p5w, dtype: int64
#
# p5d
# False    39427
# Name: p5d, dtype: int64
#
# p8m
# False    39427
# Name: p8m, dtype: int64
#
# p8w
# False    39427
# Name: p8w, dtype: int64
#
# p8d
# False    39427
# Name: p8d, dtype: int64

# %%
feature = df[[
 'categoryname',
 'ipcategory_name',
 'ipcategory_scope',
 'parent_category',
 'grandparent_category',
 'overallseverity',
 'weekday',
 'correlatedcount',
 'n1',
 'n2',
 'n3',
 'n4',
 'n5',
 'n6',
 'n7',
 'n8',
 'n9',
 'n10',
 'score',
 'srcip_cd',
 'dstip_cd',
 'srcport_cd',
 'dstport_cd',
 'alerttype_cd',
 'direction_cd',
 'eventname_cd',
 'severity_cd',
 'reportingdevice_cd',
 'devicetype_cd',
 'devicevendor_cd',
 'domain_cd',
 'protocol_cd',
 'username_cd',
 'srcipcategory_cd',
 'dstipcategory_cd',
 'isiptrusted',
 'untrustscore',
 'flowscore',
 'trustscore',
 'enforcementscore',
 'dstipcategory_dominate',
 'srcipcategory_dominate',
 'dstportcategory_dominate',
 'srcportcategory_dominate',
 'thrcnt_month',
 'thrcnt_week',
 'thrcnt_day',
 'p6',
 'p9',
 'p5m',
 'p5w',
 'p5d',
 'p8m',
 'p8w',
 'p8d']]

# %%
#mode_feature = feature[[ 'n1',
# 'n2',
# 'n3',
# 'n4',
# 'n5',
# 'n6',
# 'n7',
# 'n8',
# 'n9',
# 'n10',
# 'score']].astype("float").mode(axis=0)

feature.replace("", np.nan, inplace = True)

feature['score'].value_counts()

feature['score'].fillna(1, inplace = True)

feature.fillna(0, inplace = True)

#feature[[ 'n1',
# 'n2',
# 'n3',
# 'n4',
# 'n5',
# 'n6',
# 'n7',
# 'n8',
# 'n9',
# 'n10',
# 'score']].replace(np.nan, mode_feature, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-00eb627f3a06> in <module>
#      11 # 'score']].astype("float").mode(axis=0)
#      12
# ---> 13 feature.replace("", np.nan, inplace = True)
#      14
#      15 feature['score'].value_counts()
#
# NameError: name 'feature' is not defined

# %%
feature = pd.concat([feature,pd.get_dummies(df[['categoryname','ipcategory_name','ipcategory_scope',
                                                    'grandparent_category','weekday','dstipcategory_dominate',
                                                    'srcipcategory_dominate']])], axis=1)


feature.drop(['categoryname','ipcategory_name','ipcategory_scope',
                                                    'grandparent_category','weekday','dstipcategory_dominate',
                                                    'srcipcategory_dominate'],axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-682b1c847c4d> in <module>
# ----> 1 feature = pd.concat([feature,pd.get_dummies(df[['categoryname','ipcategory_name','ipcategory_scope',
#       2                                                     'grandparent_category','weekday','dstipcategory_dominate',
#       3                                                     'srcipcategory_dominate']])], axis=1)
#       4
#       5
#
# NameError: name 'feature' is not defined

# %%
x = feature
y = df['notified']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=4)
print ('Train set:', x_train.shape,  y_train.shape)
print ('Test set:', x_test.shape,  y_test.shape)

# %%
x_train.head(10)

# %%
x_test.head(10)

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
DT_model = DecisionTreeClassifier(criterion="entropy", max_depth = 4)
DT_model.fit(x_train,y_train)

DT_yhat = DT_model.predict(x_test)
DT_yhat_all = DT_model.predict(x)
print("DT Jaccard index: %.2f" % jaccard_similarity_score(y_test, DT_yhat))
print("DT F1-score: %.2f" % f1_score(y_test, DT_yhat, average='weighted') )

# %%
pipeline = Pipeline([('transformer', sc), ('estimator', DT_model)])

cv = KFold(n_splits=4)
scores = cross_val_score(pipeline, x, y, cv = cv)
print(scores)

# %%
SVM_model = svm.SVC()
SVM_model.fit(x_train, y_train) 

SVM_yhat = SVM_model.predict(x_test)
print("SVM Jaccard index: %.2f" % jaccard_similarity_score(y_test, SVM_yhat))
print("SVM F1-score: %.2f" % f1_score(y_test, SVM_yhat, average='weighted'))

# %%
Ks=15
mean_acc=np.zeros((Ks-1))
std_acc=np.zeros((Ks-1))
ConfustionMx=[];
for n in range(1,Ks):
    
    #Train Model and Predict  
    kNN_model = KNeighborsClassifier(n_neighbors=n).fit(x_train,y_train)
    yhat = kNN_model.predict(x_test)
    
    
    mean_acc[n-1]=np.mean(yhat==y_test);
    
    std_acc[n-1]=np.std(yhat==y_test)/np.sqrt(yhat.shape[0])
mean_acc

k = 5
#Train Model and Predict  
kNN_model = KNeighborsClassifier(n_neighbors=k).fit(x_train,y_train)

knn_yhat = kNN_model.predict(x_test)
print("KNN Jaccard index: %.2f" % jaccard_similarity_score(y_test, knn_yhat))
print("KNN F1-score: %.2f" % f1_score(y_test, knn_yhat, average='weighted'))

# %%
LR_model = LogisticRegression(C=0.01).fit(x_train,y_train)
LR_yhat = LR_model.predict(x_test)
LR_yhat_prob = LR_model.predict_proba(x_test)
print("LR Jaccard index: %.2f" % jaccard_similarity_score(y_test, LR_yhat))
print("LR F1-score: %.2f" % f1_score(y_test, LR_yhat, average='weighted') )
#print("LR LogLoss: %.2f" % log_loss(y_test, LR_yhat_prob))

# %%
data = [['Decision Tree', jaccard_similarity_score(y_test, DT_yhat), f1_score(y_test, DT_yhat, average='weighted')],
         ['SVM', jaccard_similarity_score(y_test, SVM_yhat), f1_score(y_test, SVM_yhat, average='weighted')],
         ['Logistic Regression', jaccard_similarity_score(y_test, LR_yhat), f1_score(y_test, LR_yhat, average='weighted')],
         ['KNN',jaccard_similarity_score(y_test, knn_yhat), f1_score(y_test, knn_yhat, average='weighted')]]
         #['XGB',jaccard_similarity_score(y_test, xgb_yhat),f1_score(y_test, xgb_yhat, average='weighted') ]] 
  
# Create the pandas DataFrame 
scores = pd.DataFrame(data, columns = ['Algorithm','Jaccard-score', 'F1-score',]) 
  
# print dataframe. 
print(scores)
